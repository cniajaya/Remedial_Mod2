# %% [markdown]
# Celine Kurniajaya
# JCDS07
# Remedial Modul dua
# 22 April 2020

# %% [markdown]
# For today remedial test, We would use the 1985 automotive import data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Like usual, just read the data first

# %%
auto = pd.read_csv('auto_imports.csv')

# %%
auto.head()
# Out:
#    Symboling Normalized-Loss         Make Fuel-Type Aspiration Num-of-Doors  \
# 0          3               ?  alfa-romero       gas        std          two
# 1          3               ?  alfa-romero       gas        std          two
# 2          1               ?  alfa-romero       gas        std          two
# 3          2             164         audi       gas        std         four
# 4          2             164         audi       gas        std         four
#
#     Body-Style Drive-Wheels Engine-Location  Wheel-Base  ...  Engine-Size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
# soal

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
# Symboling            201 non-null int64
# Normalized-Loss      201 non-null object
# Make                 201 non-null object
# Fuel-Type            201 non-null object
# Aspiration           201 non-null object
# Num-of-Doors         201 non-null object
# Body-Style           201 non-null object
# Drive-Wheels         201 non-null object
# Engine-Location      201 non-null object
# Wheel-Base           201 non-null float64
# Length               201 non-null float64
# Width                201 non-null float64
# Height               201 non-null float64
# Curb-Weight          201 non-null int64
# Engine-Type          201 non-null object
# Cylinders            201 non-null object
# Engine-Size          201 non-null int64
# Fuel-System          201 non-null object
# Bore                 201 non-null object
# Stroke               201 non-null object
# ...

# %%
# soal

# %%
auto.describe()
# Out:
#         Symboling  Wheel-Base      Length       Width      Height  \
# count  201.000000  201.000000  201.000000  201.000000  201.000000
# mean     0.840796   98.797015  174.200995   65.889055   53.766667
# std      1.254802    6.066366   12.322175    2.101471    2.447822
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.800000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.500000   66.600000   55.500000
# max      3.000000  120.900000  208.100000   72.000000   59.800000
#
#        Curb-Weight  Engine-Size  Compression-ratio    City-MPG  Highway-MPG  \
# count   201.000000   201.000000         201.000000  201.000000   201.000000
# mean   2555.666667   126.875622          10.164279   25.179104    30.686567
# std     517.296727    41.546834           4.004965    6.423220     6.815150
# ...

# %%
# soal

# %%
auto.describe(exclude='number')
# Out:
#        Normalized-Loss    Make Fuel-Type Aspiration Num-of-Doors Body-Style  \
# count              201     201       201        201          201        201
# unique              52      22         2          2            3          5
# top                  ?  toyota       gas        std         four      sedan
# freq                37      32       181        165          113         94
#
#        Drive-Wheels Engine-Location Engine-Type Cylinders Fuel-System  Bore  \
# count           201             201         201       201         201   201
# unique            3               2           6         7           8    39
# top             fwd           front         ohc      four        mpfi  3.62
# freq            118             198         145       157          92    23
#
#        Stroke Horsepower Peak-rpm
# count     201        201      201
# unique     37         59       23
# top       3.4         68     4800
# freq       19         19       36

# %%
# soal

# %%
latauto=[]
for i in auto.columns:
    latauto.append([i,
                    auto[i].dtypes,
                    auto[i].isna().sum(),
                    round((auto[i].isna().sum())/len(auto)*100,2),
                    auto[i].nunique(),
                    auto[i].drop_duplicates().sample(2).values]
        )
pd.DataFrame(latauto,columns=['dataFeatures','dataType','null','nullPct','unique','uniqueSample'])
# Out:
#          dataFeatures dataType  null  nullPct  unique             uniqueSample
# 0           Symboling    int64     0      0.0       6                  [1, -1]
# 1     Normalized-Loss   object     0      0.0      52               [158, 119]
# 2                Make   object     0      0.0      22  [mercedes-benz, toyota]
# 3           Fuel-Type   object     0      0.0       2            [gas, diesel]
# 4          Aspiration   object     0      0.0       2             [turbo, std]
# 5        Num-of-Doors   object     0      0.0       3                 [two, ?]
# 6          Body-Style   object     0      0.0       5   [hardtop, convertible]
# 7        Drive-Wheels   object     0      0.0       3               [rwd, fwd]
# 8     Engine-Location   object     0      0.0       2            [front, rear]
# 9          Wheel-Base  float64     0      0.0      52            [97.2, 102.4]
# 10             Length  float64     0      0.0      73           [175.4, 144.6]
# ...

# %%
# soal

# %% [markdown]
# If you realize, some columns that are numerical is listed as object data type. This is because in the data there is '?' value that become the placeholder of Null value. Now, replace all the '?' in every columns as NaN value (np.nan).

# %%
for i in auto.columns:
    auto[i] = auto[i].apply(lambda x : np.nan if x == '?' else x)

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
# Symboling            201 non-null int64
# Normalized-Loss      164 non-null object
# Make                 201 non-null object
# Fuel-Type            201 non-null object
# Aspiration           201 non-null object
# Num-of-Doors         199 non-null object
# Body-Style           201 non-null object
# Drive-Wheels         201 non-null object
# Engine-Location      201 non-null object
# Wheel-Base           201 non-null float64
# Length               201 non-null float64
# Width                201 non-null float64
# Height               201 non-null float64
# Curb-Weight          201 non-null int64
# Engine-Type          201 non-null object
# Cylinders            201 non-null object
# Engine-Size          201 non-null int64
# Fuel-System          201 non-null object
# Bore                 197 non-null object
# Stroke               197 non-null object
# ...

# %%
# soal

# %%
latauto=[]
for i in auto.columns:
    latauto.append([i,
                    auto[i].dtypes,
                    auto[i].isna().sum(),
                    round((auto[i].isna().sum())/len(auto)*100,2),
                    auto[i].nunique(),
                    auto[i].drop_duplicates().sample(2).values]
        )
pd.DataFrame(latauto,columns=['dataFeatures','dataType','null','nullPct','unique','uniqueSample'])
# Out:
#          dataFeatures dataType  null  nullPct  unique          uniqueSample
# 0           Symboling    int64     0     0.00       6                [2, 0]
# 1     Normalized-Loss   object    37    18.41      51            [154, 192]
# 2                Make   object     0     0.00      22      [jaguar, toyota]
# 3           Fuel-Type   object     0     0.00       2         [diesel, gas]
# 4          Aspiration   object     0     0.00       2          [turbo, std]
# 5        Num-of-Doors   object     2     1.00       2           [four, nan]
# 6          Body-Style   object     0     0.00       5  [convertible, sedan]
# 7        Drive-Wheels   object     0     0.00       3            [rwd, fwd]
# 8     Engine-Location   object     0     0.00       2         [front, rear]
# 9          Wheel-Base  float64     0     0.00      52         [102.0, 95.7]
# 10             Length  float64     0     0.00      73        [157.9, 177.8]
# ...

# %%
# soal

# %% [markdown]
# There are 2 columns that would be nice if they are represented as numerical value rather than written; Num-of-Doors and Cylinders. For this 2 columns, replace the string as numerical value (Ex: if it is two then replace it with 2, etc.)

# %%
auto['Num-of-Doors'].value_counts()
# Out:
# four    113
# two      86
# Name: Num-of-Doors, dtype: int64

# %%
auto['Cylinders'].value_counts()
# Out:
# four      157
# six        24
# five       10
# eight       4
# two         4
# three       1
# twelve      1
# Name: Cylinders, dtype: int64

# %%
def changenum(x):
    angka = ['one','two','three','four','five','six','seven','eight','nine','ten','eleven','twelve']
    if pd.isna(x):
        return x
    else:
        return (angka.index(x))+1

# %%
auto['Num-of-Doors'] = auto['Num-of-Doors'].apply(changenum)
auto['Cylinders'] = auto['Cylinders'].apply(changenum)

# %% [markdown]
# Now convert these following columns into float object:
# - Num-of-Doors
# - Cylinders
# - Bore
# - Stroke
# - Horsepower
# - Peak-rpm

# %%
auto['Num-of-Doors'] = auto['Num-of-Doors'].astype(float)
auto['Cylinders'] = auto['Cylinders'].astype(float)
auto['Bore'] = auto['Bore'].astype(float)
auto['Stroke'] = auto['Stroke'].astype(float)
auto['Horsepower'] = auto['Horsepower'].astype(float)
auto['Peak-rpm'] = auto['Peak-rpm'].astype(float)

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 26 columns):
# Symboling            201 non-null int64
# Normalized-Loss      164 non-null object
# Make                 201 non-null object
# Fuel-Type            201 non-null object
# Aspiration           201 non-null object
# Num-of-Doors         199 non-null float64
# Body-Style           201 non-null object
# Drive-Wheels         201 non-null object
# Engine-Location      201 non-null object
# Wheel-Base           201 non-null float64
# Length               201 non-null float64
# Width                201 non-null float64
# Height               201 non-null float64
# Curb-Weight          201 non-null int64
# Engine-Type          201 non-null object
# Cylinders            201 non-null float64
# Engine-Size          201 non-null int64
# Fuel-System          201 non-null object
# Bore                 197 non-null float64
# Stroke               197 non-null float64
# ...

# %%
# soal

# %% [markdown]
# We do not need the Symboling and Normalized Columns, so drop these 2 columns. Then, filter the data to acquire the only the row that contain NaN.

# %%
auto.drop(['Symboling','Normalized-Loss'],axis=1,inplace=True)

# %%
na = []
for i in auto.columns:
    for j,k in enumerate(auto[i]):
        if pd.isna(k):
            na.append(j)
na = [i for i in na]
na.sort()
auto.loc[na]
# Out:
#         Make Fuel-Type Aspiration  Num-of-Doors Body-Style Drive-Wheels  \
# 26     dodge       gas      turbo           NaN      sedan          fwd
# 52     mazda       gas        std           2.0  hatchback          rwd
# 52     mazda       gas        std           2.0  hatchback          rwd
# 53     mazda       gas        std           2.0  hatchback          rwd
# 53     mazda       gas        std           2.0  hatchback          rwd
# 54     mazda       gas        std           2.0  hatchback          rwd
# 54     mazda       gas        std           2.0  hatchback          rwd
# 55     mazda       gas        std           2.0  hatchback          rwd
# 55     mazda       gas        std           2.0  hatchback          rwd
# 60     mazda    diesel        std           NaN      sedan          fwd
# 126  renault       gas        std           4.0      wagon          fwd
# 126  renault       gas        std           4.0      wagon          fwd
# ...

# %%
# soal

# %% [markdown]
# Now we will try to fill the NaN value for some of the columns.
# For the NaN in Num-of-Doors, Bore, and  Stroke columns fill the NaN value with the mean of their columns with the similar value in the Make and Body-Style columns. *e.g if you have NaN in num-of-doors with hatchback renault car then fill the NaN with the num-of-doors mean of the hatchback renault car.

# %%
for col in auto.columns:
    for i in na:
        if pd.isna(auto.loc[i,col]):
            auto.loc[i,col] = auto.groupby(by=['Body-Style','Make']).mean().loc[auto.loc[i,'Body-Style'],auto.loc[i,'Make']][col]

# %% [markdown]
# Let's see once more our previous dataframe which contain the NaN to make sure that it have been filled properly

# %%
auto.loc[na]
# Out:
#         Make Fuel-Type Aspiration  Num-of-Doors Body-Style Drive-Wheels  \
# 26     dodge       gas      turbo           4.0      sedan          fwd
# 52     mazda       gas        std           2.0  hatchback          rwd
# 52     mazda       gas        std           2.0  hatchback          rwd
# 53     mazda       gas        std           2.0  hatchback          rwd
# 53     mazda       gas        std           2.0  hatchback          rwd
# 54     mazda       gas        std           2.0  hatchback          rwd
# 54     mazda       gas        std           2.0  hatchback          rwd
# 55     mazda       gas        std           2.0  hatchback          rwd
# 55     mazda       gas        std           2.0  hatchback          rwd
# 60     mazda    diesel        std           4.0      sedan          fwd
# 126  renault       gas        std           4.0      wagon          fwd
# 126  renault       gas        std           4.0      wagon          fwd
# ...

# %%
# soal

# %% [markdown]
# Now, drop all the rest row that contain the NaN value

# %%
auto.dropna(inplace=True)

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199 entries, 0 to 200
# Data columns (total 24 columns):
# Make                 199 non-null object
# Fuel-Type            199 non-null object
# Aspiration           199 non-null object
# Num-of-Doors         199 non-null float64
# Body-Style           199 non-null object
# Drive-Wheels         199 non-null object
# Engine-Location      199 non-null object
# Wheel-Base           199 non-null float64
# Length               199 non-null float64
# Width                199 non-null float64
# Height               199 non-null float64
# Curb-Weight          199 non-null int64
# Engine-Type          199 non-null object
# Cylinders            199 non-null float64
# Engine-Size          199 non-null int64
# Fuel-System          199 non-null object
# Bore                 199 non-null float64
# Stroke               199 non-null float64
# Compression-ratio    199 non-null float64
# Horsepower           199 non-null float64
# ...

# %%
# soal

# %% [markdown]
# As I am interested in the car price, I want to see if the brand of the car ('Make' column) would affecting the price. Let's try to create a visualization of it

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(8,8))
sns.countplot(x='Make',data=auto)
plt.xticks(rotation=90)
plt.title('Countplot of the car brand')
# Out:
# Text(0.5, 1.0, 'Countplot of the car brand')

# %%
# soal

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='Make',y='Price',data=auto)
plt.xticks(rotation=90)
plt.title('Mean price of each car brand')
# Out:
# Text(0.5, 1.0, 'Mean price of each car brand')

# %%
# soal

# %%
plt.figure(figsize=(8,8))
for i in auto['Make'].unique():
    sns.distplot(auto[auto['Make']==i]['Price'],kde=False,label=i)
plt.legend()
plt.title('Car price distribution for each brand')
# Out:
# Text(0.5, 1.0, 'Car price distribution for each brand')

# %%
# soal

# %% [markdown]
# ## Question 1
#
# Do you think there is a relation between the price column and the Make column? Make your reasoning.

# %%
from scipy.stats import shapiro, normaltest, anderson
def try_normal(data):
    result = {'Anderson' : {i:j for i,j in zip(anderson(data)[2], anderson(data)[1])}, 'Shapiro': shapiro(data)[1], 
     'K^2 Chi Square': normaltest(data)[1]}
    result['Anderson']['stat'] = anderson(data)[0]
    return result

# %%
try_normal(auto['Price'])
# Out:
# {'Anderson': {15.0: 0.565,
#   10.0: 0.643,
#   5.0: 0.772,
#   2.5: 0.9,
#   1.0: 1.071,
#   'stat': 11.795602420834996},
#  'Shapiro': 3.2070842140139886e-15,
#  'K^2 Chi Square': 2.2480151175285188e-17}

# %% [markdown]
# In Anderson Test, stat value > critical value --> HO Rejected. It means data is not normal distributed

# %%
from scipy.stats import mannwhitneyu

# %%
result = list(mannwhitneyu(auto[auto['Make'] != 'jaguar']['Price'], 
                        auto[auto['Make'] == 'jaguar']['Price']))
print('U-Statistic:', result[0])
print('P-Value:', result[1])
# Out:
# U-Statistic: 19.0
# P-Value: 0.002778091276308364

# %% [markdown]
# From the statistic, it seems that there are significant differences between
# the price of the category make jaguar and not jaguar. (using significance level 5%)

# %%
result = list(mannwhitneyu(auto[auto['Make'] != 'toyota']['Price'], 
                        auto[auto['Make'] == 'toyota']['Price']))
print('U-Statistic:', result[0])
print('P-Value:', result[1])
# Out:
# U-Statistic: 2053.0
# P-Value: 0.019111631045944773

# %% [markdown]
# From the statistic, it seems that there are significant differences between
# the price of the category make toyota and not toyota.

# %%
from pingouin import kruskal
kruskal(data=auto, dv='Price', between='Make')
# Out:
#         Source  ddof1        H         p-unc
# Kruskal   Make     20  123.295  6.974537e-17

# %% [markdown]
# Based on p-unc (or Uncorrected p-value) and using significance level 5%, there are relationship between make and price.

# %% [markdown]
# Create a new column called MPG-difference where the value is coming from the difference between Highway-MPG and City-MPG, then create another column called Car-Area from multipication of Length, Width, and Height columns.

# %%
auto['MPG-Differences']=auto['Highway-MPG']-auto['City-MPG']
# Out:
# C:\Users\krnjy\Anaconda3\lib\site-packages\outdated\utils.py:18: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.3.2, the latest is 0.3.3.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   **kwargs

# %%
auto['Car-Area']=auto['Length']*auto['Width']*auto['Height']

# %%
auto.head()
# Out:
#           Make Fuel-Type Aspiration  Num-of-Doors   Body-Style Drive-Wheels  \
# 0  alfa-romero       gas        std           2.0  convertible          rwd
# 1  alfa-romero       gas        std           2.0  convertible          rwd
# 2  alfa-romero       gas        std           2.0    hatchback          rwd
# 3         audi       gas        std           4.0        sedan          fwd
# 4         audi       gas        std           4.0        sedan          4wd
#
#   Engine-Location  Wheel-Base  Length  Width  ...  Bore  Stroke  \
# 0           front        88.6   168.8   64.1  ...  3.47    2.68
# 1           front        88.6   168.8   64.1  ...  3.47    2.68
# 2           front        94.5   171.2   65.5  ...  2.68    3.47
# 3           front        99.8   176.6   66.2  ...  3.19    3.40
# 4           front        99.4   176.6   66.4  ...  3.19    3.40
#
#   Compression-ratio  Horsepower  Peak-rpm City-MPG  Highway-MPG  Price  \
# ...

# %%
# soal

# %%
sns.set_style('whitegrid')
sns.distplot(auto['MPG-Differences'])

# %%
# soal

# %%
sns.set_style('whitegrid')
sns.distplot(auto['Car-Area'])

# %%
# soal

# %% [markdown]
# Now, use the IQR method to find the row outlier based on the MPG-Difference columns

# %%
q1 = auto['MPG-Differences'].quantile(.25)
q3 = auto['MPG-Differences'].quantile(.75)
iqr = q3 - q1
upper = q3 + 1.5 * iqr
lower = q1 - 1.5 * iqr

# %%
auto[(auto['MPG-Differences'] < lower )| (auto['MPG-Differences'] > upper )]
# Out:
#               Make Fuel-Type Aspiration  Num-of-Doors   Body-Style  \
# 8             audi       gas      turbo           4.0        sedan
# 47           mazda       gas        std           2.0    hatchback
# 62           mazda       gas        std           4.0        sedan
# 63           mazda    diesel        std           4.0        sedan
# 64   mercedes-benz    diesel      turbo           4.0        sedan
# 65   mercedes-benz    diesel      turbo           4.0        wagon
# 66   mercedes-benz    diesel      turbo           2.0      hardtop
# 67   mercedes-benz    diesel      turbo           4.0        sedan
# 68   mercedes-benz       gas        std           4.0        sedan
# 69   mercedes-benz       gas        std           2.0  convertible
# 70   mercedes-benz       gas        std           4.0        sedan
# 71   mercedes-benz       gas        std           2.0      hardtop
# 107         peugot    diesel      turbo           4.0        wagon
# ...

# %%
# soal

# %%
auto[(auto['MPG-Differences'] < lower )| (auto['MPG-Differences'] > upper )].describe()
# Out:
#        Num-of-Doors  Wheel-Base      Length      Width     Height  \
# count     29.000000   29.000000   29.000000  29.000000  29.000000
# mean       3.241379  102.193103  180.241379  67.406897  54.551724
# std        0.987608    9.094305   13.996671   2.863431   2.301338
# min        2.000000   89.500000  159.100000  64.000000  50.200000
# 25%        2.000000   95.700000  168.900000  65.000000  52.800000
# 50%        4.000000   97.300000  175.000000  66.100000  54.900000
# 75%        4.000000  110.000000  190.900000  70.300000  55.900000
# max        4.000000  120.900000  208.100000  72.000000  58.700000
#
#        Curb-Weight  Cylinders  Engine-Size       Bore     Stroke  \
# count    29.000000  29.000000    29.000000  29.000000  29.000000
# mean   2909.896552   5.000000   156.000000   3.465517   3.254483
# std     616.542163   1.414214    59.221738   0.279676   0.289477
# min    1890.000000   4.000000    91.000000   3.010000   2.640000
# ...

# %%
# soal

# %%
sns.distplot(auto[(auto['MPG-Differences'] < lower )| (auto['MPG-Differences'] > upper )]['Car-Area'])
plt.title('Car-Area distribution of the outlier')
# Out:
# Text(0.5, 1.0, 'Car-Area distribution of the outlier')

# %%
# soal

# %%
sns.distplot(auto[(auto['MPG-Differences'] < lower )| (auto['MPG-Differences'] > upper )]['Price'])
plt.title('Price distribution of the outlier')
# Out:
# Text(0.5, 1.0, 'Price distribution of the outlier')

# %%
# soal

# %% [markdown]
# ## Question 2
#
# From the describe, and few plots that I see it seems in our outlier based on the MPG-Differences that the car is quite big. Do you agree with my assumption? give me your reasoning

# %%
out=(auto[(auto['MPG-Differences'] < lower )| (auto['MPG-Differences'] > upper )]['MPG-Differences'])
try_normal(out)
# Out:
# {'Anderson': {15.0: 0.52,
#   10.0: 0.592,
#   5.0: 0.71,
#   2.5: 0.828,
#   1.0: 0.985,
#   'stat': 2.2112154996283664},
#  'Shapiro': 0.0002564479655120522,
#  'K^2 Chi Square': 0.0014357623294234568}

# %% [markdown]
# In Anderson Test, stat value > critical value --> HO Rejected. It means data is not normal distributed

# %%
result = list(mannwhitneyu(auto[(auto['MPG-Differences'] >= lower )| (auto['MPG-Differences'] <= upper )]['MPG-Differences'], 
                        auto[(auto['MPG-Differences'] < lower )| (auto['MPG-Differences'] > upper )]['MPG-Differences']))
print('U-Statistic:', result[0])
print('P-Value:', result[1])
# Out:
# U-Statistic: 2120.5
# P-Value: 0.009462613753198285

# %% [markdown]
# From the statistic, it seems that there are significant differences between
# the MPG-Differences of the category outlier and not outlier.

# %% [markdown]
# ## Analysis
#
# We have try to cleaning some of the data that we have, and now we could try to done few analysis from the data we had. Try to answer this following question.
#
# ### Question
#
# What do you think the feature that really affecting the price? give me your explanation with the data

# %%
auto.corr()['Price'].sort_values(ascending=False)
# Out:
# Price                1.000000
# Engine-Size          0.873887
# Curb-Weight          0.835090
# Horsepower           0.810533
# Width                0.753871
# Cylinders            0.708236
# Length               0.693965
# Car-Area             0.630859
# Wheel-Base           0.583797
# Bore                 0.545776
# Height               0.134990
# Stroke               0.093658
# Compression-ratio    0.069549
# Num-of-Doors         0.042413
# Peak-rpm            -0.101649
# MPG-Differences     -0.239476
# City-MPG            -0.689253
# Highway-MPG         -0.705230
# Name: Price, dtype: float64

# %% [markdown]
# Based on this result, top 3 features that really affecting price are: Engine-Size Feature, Curb-Weight Feature, and Horsepower Feature

# %% [markdown]
# To create our dashboard, convert your cleaned data as CSV (Just name it as auto_imports_ujian.csv, and don't forget to not including the index) and then export it to your SQL database

# %%
auto = auto.to_csv('auto_imports_ujian.csv',index=False)
